# %%
import pandas as pd
import numpy as np
import re

from nltk.corpus import stopwords
from gensim.parsing.preprocessing import STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load Dataset and combined them to get insights using 500 documents
data = pd.read_pickle('data/Hulth2003_data.pkl')
data = data[:500]

# %%
abs_sample = data['Abstract'][0]
data
# Out:
#      Doc_no                                              Title  \
# 0         6     SBC gets more serious on regulatory compliance
# 1         7  Anti-spam suit attempts to hold carriers accou...
# 2         8  New investors get steal of a deal [Global Cros...
# 3         9   Achieving competitive capabilities in e-services
# 4        11  Does social capital determine innovation? To w...
# ..      ...                                                ...
# 495     946  Entanglement measures with asymptotic weak-mon...
# 496     947  The fully entangled fraction as an inclusive m...
# 497     948  Pairwise thermal entanglement in the n-qubit (...
# 498     949  Reply to "Comment on: Teleportation of an unkn...
# 499     950                       Quantum sensitive dependence
#
#                                               Abstract  \
# 0    With one eye on the past and the other on its ...
# 1    A lawsuit alleges that Sprint has violated Uta...
# 2    Hutchison Telecommunications and Singapore Tec...
# 3    What implications does the Internet have for s...
# 4    This paper deals with two questions: Does soci...
# ..                                                 ...
# 495  We propose entanglement measures with asymptot...
# 496  Characterizing entanglement in all but the sim...
# 497  We have calculated the concurrence of the pair...
# 498  In our letter (see ibid., vol. 296, p. 161 (20...
# 499  Wave functions of bounded quantum systems with...
#
#                                               Keywords
# 0    telecommunication,SBC Communications,regulator...
# 1    electronic mail,legislation,telecommunication,...
# 2    telecommunication,Hutchison Telecommunications...
# 3    corporate modelling,electronic commerce,Intern...
# 4    corporate modelling,decision theory,manufactur...
# ..                                                 ...
# 495  quantum computing,quantum interference phenome...
# 496  information theory,quantum communication,quant...
# 497  Heisenberg model,quantum computing,quantum int...
# 498  probability,quantum communication,quantum theo...
# 499  bound states,chaos,Lyapunov methods,matrix alg...
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Checking for duplicates in the data

# %%
print(f'Shape of the Dataset before removing duplicates : {data.shape}')
duplicate = data[data.duplicated('Doc_no')]
print(f'Duplicates found in the: {duplicate.shape}')
# Out:
# Shape of the Dataset before removing duplicates : (500, 4)
# Duplicates found in the: (0, 4)

# %% [markdown]
# ### Average length of the Abstracts before Pre-Processing

# %%
total_abstracts = []
for abstract in data['Abstract']:
    total_abstracts.append(len(abstract.split()))

# %%
avg_before_proc = (sum(total_abstracts)/len(total_abstracts))
print(f"Average length of abstracts : {avg_before_proc}")
# Out:
# Average length of abstracts : 111.44

# %% [markdown]
# ### Text Pre-Processing

# %%
# Pre processing the Title text
def cleanHtml(sentence):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(sentence))
    return cleantext

def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned

def keepAlpha(sentence):
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

def removeStopWords(sentence):
    stop_words = stopwords.words('english')
    stop_words = STOPWORDS.union(set(stop_words))
    
    word_tokens = word_tokenize(sentence)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    filtered_sentence = " ".join(filtered_sentence)
    return filtered_sentence

def lemmatize(sentence):
    lemmatizer = WordNetLemmatizer()
    lem_sentence = ""
    for word in word_tokenize(sentence):
        word = lemmatizer.lemmatize(word)
        lem_sentence += word
        lem_sentence += " "
    lem_sentence = lem_sentence.strip()
    return lem_sentence
    
def getStrings(sentence):
    sentence = sentence.split(",")
    sentence = " ".join(sentence)
    return sentence

# %%
data['Abstract'] = data['Abstract'].str.lower()
data['Abstract'] = data['Abstract'].apply(cleanHtml)
data['Abstract'] = data['Abstract'].apply(cleanPunc)
data['Abstract'] = data['Abstract'].apply(keepAlpha)
data['Abstract'] = data['Abstract'].apply(removeStopWords)
data['Abstract'] = data['Abstract'].apply(lemmatize)

data['Keywords'] = data['Keywords'].str.lower()

data.head()
# Out:
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
#    Doc_no                                              Title  \
# 0       6     SBC gets more serious on regulatory compliance
# 1       7  Anti-spam suit attempts to hold carriers accou...
# 2       8  New investors get steal of a deal [Global Cros...
# 3       9   Achieving competitive capabilities in e-services
# 4      11  Does social capital determine innovation? To w...
#
#                                             Abstract  \
# 0  eye past future sbc communication week created...
# 1  lawsuit alleges sprint violated utah new anti ...
# 2  hutchison telecommunication singapore technolo...
# 3  implication internet service operation strateg...
# 4  paper deal question social capital determine i...
#
#                                             Keywords
# 0  telecommunication,sbc communications,regulator...
# 1  electronic mail,legislation,telecommunication,...
# 2  telecommunication,hutchison telecommunications...
# 3  corporate modelling,electronic commerce,intern...
# 4  corporate modelling,decision theory,manufactur...

# %% [markdown]
# ### Comparing a row from the abstract column before and after text-processing

# %%
print(f'Length before pre-processing : {len(abs_sample.split())}\n')
print(abs_sample)
# Out:
# Length before pre-processing : 79
#
# With one eye on the past and the other on its future, SBC Communications last week created a unit it hopes will bring a cohesiveness and efficiency to its regulatory compliance efforts that previously had been lacking. The carrier also hopes the new regulatory compliance unit will help it accomplish its short-term goal of landing FCC approval. to provide long-distance service throughout its region, and its longer-term, goal of reducing the regulatory burdens under which it and currently operate

# %%
procs_abs_sample = data['Abstract'][0]
print(f'Length after pre-processing : {len(procs_abs_sample.split())}\n')
print(procs_abs_sample)
# Out:
# Length after pre-processing : 44
#
# eye past future sbc communication week created unit hope bring cohesiveness efficiency regulatory compliance effort previously lacking carrier hope new regulatory compliance unit help accomplish short term goal landing fcc approval provide long distance service region longer term goal reducing regulatory burden currently operate

# %% [markdown]
# ### Average length of the abstracts after pre-processing

# %%
total_abstracts = []
for abstract in data['Abstract']:
    total_abstracts.append(len(abstract.split()))

# %%
avg_after_proc = (sum(total_abstracts)/len(total_abstracts))
print(f"Average length of abstracts : {avg_after_proc}")
# Out:
# Average length of abstracts : 63.464

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
desc = ['Avg before Pre-Processing', 'Avg after Pre-Processing']
average_score = [avg_before_proc, avg_after_proc]
ax.bar(desc,average_score)
plt.title('COMPARING THE AVERAGE LENGTH OF THE ABSTRACTS BEFORE AND AFTER DATA PRE-PROCESSING')
plt.show()

# %%
data.head()
# Out:
#    Doc_no                                              Title  \
# 0       6     SBC gets more serious on regulatory compliance
# 1       7  Anti-spam suit attempts to hold carriers accou...
# 2       8  New investors get steal of a deal [Global Cros...
# 3       9   Achieving competitive capabilities in e-services
# 4      11  Does social capital determine innovation? To w...
#
#                                             Abstract  \
# 0  eye past future sbc communication week created...
# 1  lawsuit alleges sprint violated utah new anti ...
# 2  hutchison telecommunication singapore technolo...
# 3  implication internet service operation strateg...
# 4  paper deal question social capital determine i...
#
#                                             Keywords
# 0  telecommunication,sbc communications,regulator...
# 1  electronic mail,legislation,telecommunication,...
# 2  telecommunication,hutchison telecommunications...
# 3  corporate modelling,electronic commerce,intern...
# 4  corporate modelling,decision theory,manufactur...

# %%
pd.to_pickle(data, 'Data/Processed_Hulth.pkl')
