# %%
# Importing essential modules for the algorithms
from rake_nltk import Rake
import yake
from keybert import KeyBERT
from sklearn.decomposition import LatentDirichletAllocation
import spacy
import pytextrank


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from numpy import array, log

# data processing
import pandas as pd

# %% [markdown]
# ### Importing the dataset
# - The dataset is pre-processed from the "Pre-Processing-NLM500.ipynb" file

# %%
data = pd.read_pickle('Data/Processed_NLM500.pkl')
data.head()
# Out:
#    Doc_no                                           Abstract  \
# 0     100  poor oxidation behavior major barrier increase...
# 1     101  key problem inspector access data small inspec...
# 2     102  situ oxidation experiment carried mm diameter ...
# 3     103  study outline trial transient response analysi...
# 4     104  result type oxidation test combined study tabl...
#
#                                             Keywords
# 0  alloys,alloys with substantially improved oxid...
# 1  block,build a model of the smallest thicknesse...
# 2  3mm diameter discs,accelerating voltage of 30k...
# 3  assessment of the corrosion condition,assess t...
# 4  adjusted to accommodate buoyancy effects,alumi...

# %%
docs = data['Abstract'].tolist()

# %%
doc_no = data['Doc_no'].tolist()

# %% [markdown]
# ### RAKE Algorithm
# - The following code block uses the rake_nltk module to extract ketwords from the document

# %%
# This function takes in the text from the datafame and returns keywords
def get_rake_keywords(docs):
    r = Rake(min_length=2, max_length=3)
    sr_no = 1
    results = []
    for row in docs:
        #print(f'Processing : {sr_no}')
        r.extract_keywords_from_text(row)
        keywords = r.get_ranked_phrases()
        keywords = keywords[:10]
        keywords = ",".join(keywords)
        results.append(keywords)
        sr_no += 1
    rake_df = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    rake_df.insert(loc=0, column="Doc_no", value=doc_no)
    return rake_df

# %%
# Since Rake algorithm did not work well with pre-processed data, we applied the abstract from the 
rake_df = pd.read_pickle('Data/NLM500_data.pkl')
rake_docs = rake_df['Abstract'].tolist()
rake_pred_df = get_rake_keywords(rake_docs)

# %%
pd.to_pickle(rake_pred_df, 'nlm_results/rake_pred_df.pkl')
rake_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       100  Poor oxidation behavior is the major barrier t...
# 1       101  A key part of this problem is that an inspecto...
# 2       102  In situ oxidation, experiments were carried ou...
# 3       103  The study outlines a trial of transient respon...
# 4       104  The results from two types of oxidation test a...
# ..      ...                                                ...
# 488     588  MicroCT has been applied to AM parts in variou...
# 489     589  Aeroengine turbine disks often consist of para...
# 490     590  Although the presented model is developed and ...
# 491     591  Power and particle exhaust are crucial for the...
# 492     592  The main drawback of thermo-oxidation in most ...
#
#                                     Extracted_Keywords
# 0    requires careful study,broader compositional r...
# 1    small inspected area,provide enough informatio...
# 2    transmission electron microscope,primary beam ...
# 3    transient response analysis,term benefits prov...
# 4    table 1 shows,horizontal tube furnaces,accommo...
# ..                                                 ...
# 488  preliminary results demonstrating,hot isostati...
# 489  known hysteresis behaviour,remaining flux dens...
# 490  single outer surface,carbon based materials,nu...
# 491  severe technical challenge,presumably dramatic...
# 492  previous works done,large heat loads,hot heliu...
#
# [493 rows x 3 columns]

# %% [markdown]
# ### YAKE Algorithm
# - The following code block uses the yake module to get keywords from the document

# %%
# This function takes in the text from the datafame and returns keywords
def get_yake_keywords(docs):
    kw_extractor = yake.KeywordExtractor(n=3, top=10)
    results = []
    for row in docs:
        keywords = kw_extractor.extract_keywords(row)
        keys = []
        for val in keywords:
            keys.append(val[0])
        results.append(",".join(keys))
    yake_df = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    yake_df.insert(loc=0, column="Doc_no", value=doc_no)
    return yake_df

# %%
yake_pred_df = get_yake_keywords(docs)

# %%
pd.to_pickle(yake_pred_df, 'nlm_results/yake_pred_df.pkl')
yake_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       100  poor oxidation behavior major barrier increase...
# 1       101  key problem inspector access data small inspec...
# 2       102  situ oxidation experiment carried mm diameter ...
# 3       103  study outline trial transient response analysi...
# 4       104  result type oxidation test combined study tabl...
# ..      ...                                                ...
# 488     588  microct applied part form preliminary result d...
# 489     589  aeroengine turbine disk consist paramagnetic m...
# 490     590  presented model developed tested c h layer min...
# 491     591  power particle exhaust crucial viability futur...
# 492     592  main drawback thermo oxidation actual device i...
#
#                                     Extracted_Keywords
# 0    based alloy,oxidation behavior,behavior major,...
# 1    thickness measurement,smallest thickness,minim...
# 2    sample heated,situ oxidation,tem sample,heated...
# 3    transient response,response analysis,ass long,...
# 4    table show,time interval,test conducted,result...
# ..                                                 ...
# 488  average porosity,build direction,porosity stru...
# 489  aeroengine turbine,turbine disk,magnetic field...
# 490  presented model,forming volatile,model develop...
# 491  fusion reactor,crucial viability,viability fut...
# 492  strike point,carbon deposit,carbon material,un...
#
# [493 rows x 3 columns]

# %% [markdown]
# ## TF-IDF
# - The following code block uses the TF-IDF method from the Scikit-Learn module

# %%
def get_tf_idf_keywords(docs):
    results = []
    for row in docs:
        vectorizer = CountVectorizer(ngram_range = (2,3))
        X1 = vectorizer.fit_transform([row]) 
        features = (vectorizer.get_feature_names())
        vectorizer = TfidfVectorizer(ngram_range = (2,3))
        X2 = vectorizer.fit_transform([row])
        scores = (X2.toarray())
        sums = X2.sum(axis = 0)
        data1 = []
        for col, term in enumerate(features):
            data1.append( (term, sums[0,col] ))
        ranking = pd.DataFrame(data1, columns = ['term','rank'])
        words = (ranking.sort_values('rank', ascending = False))
        ex_keywords = []
        for term in words['term'][:10]:
            ex_keywords.append(term)
        results.append(",".join(ex_keywords))
    tf_idf_df = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    tf_idf_df.insert(loc=0, column="Doc_no", value=doc_no)
    return tf_idf_df

# %%
tf_idf_pred_df = get_tf_idf_keywords(docs)

# %%
pd.to_pickle(tf_idf_pred_df, 'nlm_results/tf_idf_pred_df.pkl')
tf_idf_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       100  poor oxidation behavior major barrier increase...
# 1       101  key problem inspector access data small inspec...
# 2       102  situ oxidation experiment carried mm diameter ...
# 3       103  study outline trial transient response analysi...
# 4       104  result type oxidation test combined study tabl...
# ..      ...                                                ...
# 488     588  microct applied part form preliminary result d...
# 489     589  aeroengine turbine disk consist paramagnetic m...
# 490     590  presented model developed tested c h layer min...
# 491     591  power particle exhaust crucial viability futur...
# 492     592  main drawback thermo oxidation actual device i...
#
#                                     Extracted_Keywords
# 0    based alloy,oxidation behavior,ti based alloy,...
# 1    thickness measurement,smallest thickness,small...
# 2    tem sample,sample heated,accelerating voltage,...
# 3    transient response,protective current,response...
# 4    table show,time interval,test conducted,accomm...
# ..                                                 ...
# 488  average porosity,porosity structure,build dire...
# 489  aeroengine turbine,non magnetic,magnetic field...
# 490  forming volatile,presented model,allow applyin...
# 491  fusion reactor,limit term material,pfc reach,p...
# 492  strike point,carbon deposit,carbon material,us...
#
# [493 rows x 3 columns]

# %% [markdown]
# ### KeyBert Algorithm

# %%
def get_keybert_keywords(docs):
    model = KeyBERT('distilbert-base-nli-mean-tokens')
    results = []
    doc_no = 1
    for row in docs:
        keywords = model.extract_keywords(row, keyphrase_ngram_range=(2, 3), stop_words=None)
        temp_keys = []
        for val in keywords:
            temp_keys.append(val[0])
        results.append(",".join(temp_keys))
        doc_no += 1
    key_bert_df = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    key_bert_df.insert(loc=0, column="Doc_no", value=doc_no)
    return key_bert_df

# %%
key_bert_pred_df = get_keybert_keywords(docs)

# %%
pd.to_pickle(key_bert_pred_df, 'nlm_results/key_bert_pred_df.pkl')
key_bert_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       494  poor oxidation behavior major barrier increase...
# 1       494  key problem inspector access data small inspec...
# 2       494  situ oxidation experiment carried mm diameter ...
# 3       494  study outline trial transient response analysi...
# 4       494  result type oxidation test combined study tabl...
# ..      ...                                                ...
# 488     494  microct applied part form preliminary result d...
# 489     494  aeroengine turbine disk consist paramagnetic m...
# 490     494  presented model developed tested c h layer min...
# 491     494  power particle exhaust crucial viability futur...
# 492     494  main drawback thermo oxidation actual device i...
#
#                                     Extracted_Keywords
# 0    improved oxidation resistance,oxidation techni...
# 1    thickness measurement partitioning,minimum thi...
# 2    electron detector sample,collected nanolab sca...
# 3    analysis scale motorway,scale motorway bridge,...
# 4    oxidation test combined,furnace test batch,the...
# ..                                                 ...
# 488  study porosity structure,reported study porosi...
# 489  magnetometer magnetic remanence,flux gate magn...
# 490  nuclear fusion device,way nuclear fusion,nucle...
# 491  fusion reactor severe,density fusion reactor,f...
# 492  experimental nuclear fusion,reconditioning wal...
#
# [493 rows x 3 columns]

# %% [markdown]
# ### Latent Dirichlet Allocation

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return topic_dict

# %%
def get_lda_keywords(docs):
    results = []
    for row in docs:
        vectorizer = CountVectorizer(ngram_range=(3,3))
        tf = vectorizer.fit_transform([row])
        tf_feature_names = vectorizer.get_feature_names()
        number_of_topics = 1
        model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)
        model.fit(tf)
        no_top_words = 10
        result_dict = display_topics(model, tf_feature_names, no_top_words)
        kw = result_dict['Topic 0 words']
        results.append(",".join(kw))
    lda = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    lda.insert(loc=0, column="Doc_no", value=doc_no)
    return lda

# %%
lda_pred_df = get_lda_keywords(docs)

# %%
pd.to_pickle(lda_pred_df, 'nlm_results/lda_pred_df.pkl')
lda_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       100  poor oxidation behavior major barrier increase...
# 1       101  key problem inspector access data small inspec...
# 2       102  situ oxidation experiment carried mm diameter ...
# 3       103  study outline trial transient response analysi...
# 4       104  result type oxidation test combined study tabl...
# ..      ...                                                ...
# 488     588  microct applied part form preliminary result d...
# 489     589  aeroengine turbine disk consist paramagnetic m...
# 490     590  presented model developed tested c h layer min...
# 491     591  power particle exhaust crucial viability futur...
# 492     592  main drawback thermo oxidation actual device i...
#
#                                     Extracted_Keywords
# 0    ti based alloy,use ti based,expected relation ...
# 1    smallest thickness measurement,sample smallest...
# 2    xl feg esem,esem hot stage,examined leo vp,exp...
# 3    transient response analysis,ass long term,year...
# 4    weight change test,weighing room temperature,e...
# ..                                                 ...
# 488  work report similar,hip treatment sample,direc...
# 489  aeroengine turbine disk,turbine disk consist,f...
# 490  way nuclear fusion,fusion device possibly,devi...
# 491  wall exhausted volumetrically,volumetrically l...
# 492  work treatment iter,homogeneous vessel limited...
#
# [493 rows x 3 columns]

# %% [markdown]
# ### PositionRank Algorithm

# %%
def get_textrank_keywords(docs):
    results = []
    for row in docs:
        # load a spaCy model
        nlp = spacy.load("en_core_web_sm")

        # add PyTextRank to the spaCy pipeline
        nlp.add_pipe("positionrank") #positionrank
        doc = nlp(row)

        # examine the top-ranked phrases in the document
        limit = len(doc._.phrases)
        kw = []
        if(limit > 4):
            for phrase in doc._.phrases:
                if(len(phrase.text.split()) <= 4 and len(phrase.text.split()) > 1):
                    kw.append(phrase.text)
            kw = ",".join(kw)
            results.append(kw)
        else:
            for phrase in doc._.phrases:
                kw.append(phrase.text)
            kw = ",".join(kw)
            results.append(kw)
    pos_rank_df = pd.DataFrame(zip(docs,results),columns=['Abstract','Extracted_Keywords'])
    pos_rank_df.insert(loc=0, column="Doc_no", value=doc_no)
    return pos_rank_df

# %%
pos_rank_pred_df = get_textrank_keywords(docs)

# %%
pd.to_pickle(pos_rank_pred_df, 'nlm_results/pos_rank_pred_df.pkl')
pos_rank_pred_df
# Out:
#      Doc_no                                           Abstract  \
# 0       100  poor oxidation behavior major barrier increase...
# 1       101  key problem inspector access data small inspec...
# 2       102  situ oxidation experiment carried mm diameter ...
# 3       103  study outline trial transient response analysi...
# 4       104  result type oxidation test combined study tabl...
# ..      ...                                                ...
# 488     588  microct applied part form preliminary result d...
# 489     589  aeroengine turbine disk consist paramagnetic m...
# 490     590  presented model developed tested c h layer min...
# 491     591  power particle exhaust crucial viability futur...
# 492     592  main drawback thermo oxidation actual device i...
#
#                                     Extracted_Keywords
# 0    based alloy,service temperature alloy,producti...
# 1    smallest thickness inspector,underlying thickn...
# 2    situ oxidation experiment,esem hot stage,pa ex...
# 3    interruption protective current structure,impr...
# 4    h test test,time interval specimen,furnace tem...
# ..                                                 ...
# 488  sample average porosity study,similar porosity...
# 489  non magnetic material,aeroengine turbine disk,...
# 490  volatile reactive gas e,presented model,consti...
# 491  conventional concept material plasma,neutron i...
# 492  homogeneous vessel limited distance,oxygen tem...
#
# [493 rows x 3 columns]
